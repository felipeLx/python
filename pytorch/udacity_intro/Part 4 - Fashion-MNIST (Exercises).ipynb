# %% [markdown]
# # Classifying Fashion-MNIST
#
# Now it's your turn to build and train a neural network. You'll be using the [Fashion-MNIST dataset](https://github.com/zalandoresearch/fashion-mnist), a drop-in replacement for the MNIST dataset. MNIST is actually quite trivial with neural networks where you can easily achieve better than 97% accuracy. Fashion-MNIST is a set of 28x28 greyscale images of clothes. It's more complex than MNIST, so it's a better representation of the actual performance of your network, and a better representation of datasets you'll use in the real world.
#
# <img src='assets/fashion-mnist-sprite.png' width=500px>
#
# In this notebook, you'll build your own neural network. For the most part, you could just copy and paste the code from Part 3, but you wouldn't be learning. It's important for you to write the code yourself and get it to work. Feel free to consult the previous notebooks though as you work through this.
#
# First off, let's load the dataset through torchvision.

# %%
import torch
from torchvision import datasets, transforms
import helper_utils

# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,))])
# Download and load the training data
trainset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# Download and load the test data
testset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to /home/felipelx/.pytorch/F_MNIST_data/FashionMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting /home/felipelx/.pytorch/F_MNIST_data/FashionMNIST/raw/train-images-idx3-ubyte.gz to /home/felipelx/.pytorch/F_MNIST_data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to /home/felipelx/.pytorch/F_MNIST_data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting /home/felipelx/.pytorch/F_MNIST_data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to /home/felipelx/.pytorch/F_MNIST_data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to /home/felipelx/.pytorch/F_MNIST_data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting /home/felipelx/.pytorch/F_MNIST_data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to /home/felipelx/.pytorch/F_MNIST_data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to /home/felipelx/.pytorch/F_MNIST_data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting /home/felipelx/.pytorch/F_MNIST_data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to /home/felipelx/.pytorch/F_MNIST_data/FashionMNIST/raw

# %% [markdown]
# Here we can see one of the images.

# %%
image, label = next(iter(trainloader))
helper_utils.imshow(image[0,:]);

# %% [markdown]
# ## Building the network
#
# Here you should define your network. As with MNIST, each image is 28x28 which is a total of 784 pixels, and there are 10 classes. You should include at least one hidden layer. We suggest you use ReLU activations for the layers and to return the logits or log-softmax from the forward pass. It's up to you how many layers you add and the size of those layers.

# %%
# TODO: Define your network architecture here
from torch import nn, optim
import torch.nn.functional as F

class Classifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256,128)
        self.fc3 = nn.Linear(128,64)
        self.fc4 = nn.Linear(64,10)
    
    def forward(self, x):
        x = x.view(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.log_softmax(self.fc4(x), dim=1)

        return x

# %% [markdown]
# # Train the network
#
# Now you should create your network and train it. First you'll want to define [the criterion](http://pytorch.org/docs/master/nn.html#loss-functions) ( something like `nn.CrossEntropyLoss`) and [the optimizer](http://pytorch.org/docs/master/optim.html) (typically `optim.SGD` or `optim.Adam`).
#
# Then write the training code. Remember the training pass is a fairly straightforward process:
#
# * Make a forward pass through the network to get the logits
# * Use the logits to calculate the loss
# * Perform a backward pass through the network with `loss.backward()` to calculate the gradients
# * Take a step with the optimizer to update the weights
#
# By adjusting the hyperparameters (hidden units, learning rate, etc), you should be able to get the training loss below 0.4.

# %%
# TODO: Create the network, define the criterion and optimizer
model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.003)

epochs = 6
for epoch in range(epochs):
    running_loss = 0
    for images, labels in trainloader:
        # images = images.view(images.shape[0], -1)
        optimizer.zero_grad()
        output = model.forward(images)
        loss = criterion(output, labels)
        print('loss after: ', loss)
        loss.backward()
        optimizer.step()
        print('loss before: ', loss)

        running_loss += loss.item()
    else:
        print(f'Training loss: {running_loss/len(trainloader)}')
# Out:
# loss after:  tensor(2.3038, grad_fn=<NllLossBackward0>)
# /home/felipelx/.local/lib/python3.8/site-packages/torch/autograd/__init__.py:173: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:112.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# loss before:  tensor(2.3038, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3096, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3096, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3049, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3049, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3127, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3127, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3083, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3083, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3014, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3014, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3029, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3029, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2955, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2955, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2998, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2998, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2907, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2907, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2952, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2952, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2974, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2974, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2938, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2938, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3088, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3088, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3027, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3027, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3019, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3019, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2896, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2896, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2891, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2891, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3091, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3091, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3038, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3038, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2982, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2982, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3006, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3006, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2974, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2974, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3017, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3017, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2911, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2911, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2978, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2978, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3042, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3042, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2942, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2942, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2965, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2965, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3033, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3033, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2895, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2895, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2921, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2921, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2933, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2933, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2921, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2921, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3024, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3024, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3003, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3003, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2989, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2989, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2948, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2948, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3043, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3043, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2936, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2936, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2980, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2980, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2927, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2927, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2965, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2965, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3049, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3049, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2922, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2922, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3040, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3040, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2938, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2938, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2911, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2911, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2919, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2919, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2902, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2902, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2897, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2897, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2943, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2943, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2957, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2957, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2876, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2876, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2815, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2815, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2866, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2866, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2968, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2968, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2942, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2942, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2999, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2999, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2868, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2868, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2814, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2814, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2871, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2871, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2942, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2942, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.3019, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.3019, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2920, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2920, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2918, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2918, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2872, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2872, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2855, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2855, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2943, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2943, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2885, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2885, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2903, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2903, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2839, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2839, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2862, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2862, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2928, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2928, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2903, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2903, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2896, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2896, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2853, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2853, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2894, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2894, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2943, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2943, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2865, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2865, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2901, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2901, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2883, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2883, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2790, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2790, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2841, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2841, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2767, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2767, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2851, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2851, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2773, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2773, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2824, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2824, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2934, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2934, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2879, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2879, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2903, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2903, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2881, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2881, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2839, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2839, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2873, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2873, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2873, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2873, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2906, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2906, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2812, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2812, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2839, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2839, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2846, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2846, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2783, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2783, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2808, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2808, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2899, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2899, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2820, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2820, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2771, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2771, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2818, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2818, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2912, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2912, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2842, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2842, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2910, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2910, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2813, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2813, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2862, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2862, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2749, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2749, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2751, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2751, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2818, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2818, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2840, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2840, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2836, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2836, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2840, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2840, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2837, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2837, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2829, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2829, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2735, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2735, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2810, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2810, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2824, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2824, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2775, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2775, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2810, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2810, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2832, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2832, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2805, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2805, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2858, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2858, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2821, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2821, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2746, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2746, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2793, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2793, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2795, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2795, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2777, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2777, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2839, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2839, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2776, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2776, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2776, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2776, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2794, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2794, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2722, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2722, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2773, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2773, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2849, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2849, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2699, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2699, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2748, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2748, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2827, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2827, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2794, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2794, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2720, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2720, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2770, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2770, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2769, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2769, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2764, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2764, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2692, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2692, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2763, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2763, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2743, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2743, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2814, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2814, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2751, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2751, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2689, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2689, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2801, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2801, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2837, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2837, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2703, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2703, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2701, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2701, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2673, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2673, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2719, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2719, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2636, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2636, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2669, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2669, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2758, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2758, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2823, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2823, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2741, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2741, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2836, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2836, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2784, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2784, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2781, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2781, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2732, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2732, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2779, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2779, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2687, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2687, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2701, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2701, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2724, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2724, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2743, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2743, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2663, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2663, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2740, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2740, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2769, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2769, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2688, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2688, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2709, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2709, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2672, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2672, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2710, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2710, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2741, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2741, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2681, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2681, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2735, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2735, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2656, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2656, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2692, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2692, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2711, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2711, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2744, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2744, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2650, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2650, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2675, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2675, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.
grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.1979, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2012, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2012, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2158, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2158, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2008, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2008, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2135, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2135, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2059, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2059, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.1990, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.1990, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2037, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2037, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2197, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2197, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2061, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2061, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2030, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2030, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2054, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2054, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2116, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2116, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2166, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2166, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2079, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2079, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2011, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2011, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.1859, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.1859, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.1997, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.1997, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2016, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2016, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.1972, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.1972, grad_fn=<NllLossBackward0>)
# loss after:  tensor(2.2199, grad_fn=<NllLossBackward0>)
# loss before:  tensor(2.2199, grad_fn=<NllLossBackward0>)
# ...
# loss after:  tensor(0.6291, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6291, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4140, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4140, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5581, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5581, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6634, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6634, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5281, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5281, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4914, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4914, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4913, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4913, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.3237, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.3237, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4559, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4559, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5417, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5417, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4181, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4181, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5122, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5122, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.7309, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.7309, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6281, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6281, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5512, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5512, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6628, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6628, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6329, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6329, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5519, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5519, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5164, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5164, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5904, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5904, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5388, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5388, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5264, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5264, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.7343, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.7343, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5429, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5429, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6665, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6665, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4490, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4490, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4357, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4357, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6209, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6209, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5030, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5030, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5281, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5281, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4994, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4994, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5697, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5697, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5401, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5401, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5128, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5128, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5584, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5584, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5411, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5411, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6236, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6236, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5366, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5366, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6918, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6918, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6756, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6756, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4808, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4808, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4523, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4523, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5511, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5511, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6320, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6320, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4646, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4646, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4698, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4698, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5984, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5984, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6110, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6110, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5792, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5792, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4469, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4469, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6065, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6065, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4666, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4666, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6526, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6526, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5455, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5455, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4938, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4938, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4538, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4538, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5981, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5981, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5966, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5966, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5490, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5490, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4350, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4350, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5200, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5200, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6969, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6969, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5121, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5121, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5778, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5778, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5924, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5924, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5698, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5698, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4899, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4899, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5475, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5475, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6425, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6425, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5953, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5953, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5906, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5906, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4646, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4646, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.3817, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.3817, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5206, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5206, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5494, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5494, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4931, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4931, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4989, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4989, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5305, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5305, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6690, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6690, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4895, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4895, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4621, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4621, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.7444, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.7444, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.7325, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.7325, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6012, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6012, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6852, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6852, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6496, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6496, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4401, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4401, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4638, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4638, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5849, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5849, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4440, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4440, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4795, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4795, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6709, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6709, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6757, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6757, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4259, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4259, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4893, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4893, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6539, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6539, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5172, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5172, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5873, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5873, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5708, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5708, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6989, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6989, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.7089, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.7089, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.3839, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.3839, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6037, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6037, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4369, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4369, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.7264, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.7264, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4730, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4730, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4490, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4490, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5114, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5114, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.3438, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.3438, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4731, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4731, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6906, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6906, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5122, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5122, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.7379, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.7379, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5898, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5898, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5566, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5566, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6167, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6167, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4573, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4573, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5200, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5200, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6447, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6447, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5679, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5679, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5293, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5293, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5579, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5579, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6045, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6045, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4512, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4512, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4535, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4535, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5541, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5541, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4969, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4969, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6214, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6214, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4885, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4885, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.8343, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.8343, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6537, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6537, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5331, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5331, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6664, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6664, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5097, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5097, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6670, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6670, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4409, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4409, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5894, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5894, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.6889, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.6889, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5388, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5388, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.5323, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.5323, grad_fn=<NllLossBackward0>)
# loss after:  tensor(0.4128, grad_fn=<NllLossBackward0>)
# loss before:  tensor(0.4128, grad_fn=<NllLossBackward0>)
# Training loss: 0.5699443160725046

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper_utils

# Test out your network!

dataiter = iter(testloader)
images, labels = dataiter.next()
img = images[0]
# Convert 2D image to 1D vector
img = img.resize_(1, 784)

# TODO: Calculate the class probabilities (softmax) for img
with torch.no_grad():
    logps = model(img)
ps = torch.exp(logps)

# Plot the image and probabilities
helper_utils.view_classify(img.resize_(1, 28, 28), ps, version='Fashion')
